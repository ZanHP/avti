# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
tabela = pd.read_csv('vozila 14_1 brez hudih porab brez hudih moci.csv', sep=';', encoding='latin1', low_memory=False)
tabela
tabela = tabela[['Registrsko obmocje', 'Znamka', 'Masa', 'ccm', 'Moc', 'Gorivo',
                 'Najvisja hitrost', 'CO2', 'poraba 10x', 'Okoljevarstvena oznaka', 'Leto izdelave']]
tabela['poraba 10x'] = tabela['poraba 10x']/10
tabela.columns = ['Registrsko obmocje', 'Znamka', 'Masa', 'ccm', 'Moc', 'Gorivo',
                 'Najvisja hitrost', 'CO2', 'Poraba goriva', 'Okoljevarstvena oznaka', 'Leto izdelave']

# %%
tabela[:10]
# Out:
#   Registrsko obmocje    Znamka  Masa   ccm  Moc Gorivo  Najvisja hitrost  \
# 0              KOPER  MASERATI  2045  4244  295      P               275
# 1              KRANJ      FORD  1688  4009  157      P               217
# 2      MURSKA SOBOTA   HYUNDAI  1820  2476   73      D               136
# 3         NOVO MESTO   HYUNDAI  1820  2476   73      D               136
# 4         NOVO MESTO       KIA  1501  1998   94      P               172
# 5         NOVO MESTO       KIA  1478  1997  100      P               207
# 6              CELJE       BMW  1170  1596   73      P               179
# 7          LJUBLJANA       KIA  1189  1594   75      P               186
# 8          LJUBLJANA       KIA  1114  1594   75  P/LPG               186
# 9              CELJE       KIA  1114  1594   74      P               186
#
#       CO2  Poraba goriva  Okoljevarstvena oznaka  Leto izdelave
# 0  442.70           18.9                       3           2005
# 1  300.80           12.6                       4           2005
# 2  287.80           10.9                       2           1999
# 3  287.80           10.9                       3           2000
# 4  260.90           11.0                       2           2000
# 5  204.30            8.6                       3           2005
# 6  199.52            6.7                       2           1993
# 7  190.40            8.0                       3           2004
# 8  190.40            8.0                       3           2003
# 9  190.40            8.0                       3           2004

# %% [markdown]
# # 1. Znamke po Sloveniji

# %% [markdown]
# Za predstavo, kateri avtomobili se vozijo po slovenskih cestah, si oglejmo njihovo porazdelitev po 10 najbolj pogosto zastopanih znamkah.

# %%
a = tabela.groupby('Registrsko obmocje')['Znamka']
pogoste = ['RENAULT', 'VOLKSWAGEN', 'OPEL', 'CITROEN', 'PEUGEOT', 'FORD', 'SKODA', 'AUDI', 'BMW', 'HYUNDAI']
zn = pd.DataFrame(a.value_counts()).unstack()['Znamka'][pogoste]
zn
vsote = pd.DataFrame(zn.sum(axis = 1))

zn_norm = zn.div(zn.sum(axis=1), axis=0)

# %%
znamke = tabela.groupby('Znamka')
znamke.size().sort_values(ascending=False)[:10].plot(kind='pie',figsize=(4, 4), fontsize=8, autopct='%1.1f%%', colormap='spectral_r')

# %%
zn_norm.plot(kind='bar', stacked=True, colormap='spectral_r', legend=False)
plt.legend(fontsize=10, loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# Največji delež predstavljajo znamke Renault, Volkswagen in Opel.
#
# V diagramu, ki kaže zastopanost znamk v posameznem registrskem območju, opazimo, da je porazdelitev, razen nekaj izjem, dokaj podobna v vseh območjih.
#
# Najbolj izstopa relativno visoka pogostost Opla v Postojni.

# %% [markdown]
# # 2. Parametri po registrskih območjih

# %% [markdown]
# ## 2.1 Število avtomobilov

# %%
stevilo = tabela.groupby('Registrsko obmocje')
stevilo.size().sort_values(ascending=False).plot(kind='bar',figsize=(6, 4))

# %% [markdown]
# Ni presenetljivo, da je več avtomobilov v krajih z več prebivalci. Žal se statistične regije ne ujemajo z registrskimi območji in izračun, koliko avtomobilov povprečno ima prebivalecv posameznem območju, ni mogoč.
#
# Lahko pa raziščemo, kje so avtomobili najbolj ekološki, najmočnejši in najnovejši.

# %% [markdown]
# ## 2.2 Poraba goriva in izpust CO2

# %% [markdown]
# Začnimo z analizo porabe goriva in izpustom CO2. Predvidevamo, da tam, kjer imajo avtomobili večjo porabo goriva, izpuščajo tudi več CO2.

# %%
poraba = tabela[['Registrsko obmocje', 'Poraba goriva', 'CO2', 'ccm']]

# %%
skupna_po_krajih = round(poraba.groupby('Registrsko obmocje')[['CO2', 'Poraba goriva', 'ccm']].mean(), 3)

PORABA = pd.DataFrame(skupna_po_krajih).sort_values('Poraba goriva', ascending=False)

PORABA['CO2%'] = round((PORABA['CO2'] - min(PORABA['CO2'])) / (max(PORABA['CO2']) - min(PORABA['CO2'])), 3)
PORABA['gorivo%'] = round((PORABA['Poraba goriva'] - min(PORABA['Poraba goriva'])) / (max(PORABA['Poraba goriva']) - min(PORABA['Poraba goriva'])), 3)
PORABA['ccm%'] = round((PORABA['ccm'] - min(PORABA['ccm'])) / (max(PORABA['ccm']) - min(PORABA['ccm'])), 3)

PORABA['|ccm% - gorivo%|'] = abs(PORABA['ccm%'] - PORABA['gorivo%'])

PORABA.reset_index()
# Out:
#    Registrsko obmocje      CO2  Poraba goriva       ccm   CO2%  gorivo%  \
# 0         NOVA GORICA  147.835          5.910  1657.053  1.000    1.000
# 1      SLOVENJ GRADEC  147.155          5.889  1659.261  0.879    0.917
# 2       MURSKA SOBOTA  144.412          5.859  1574.804  0.392    0.798
# 3               KRANJ  146.108          5.855  1636.617  0.693    0.782
# 4            POSTOJNA  145.684          5.847  1621.582  0.618    0.750
# 5             MARIBOR  144.788          5.813  1625.649  0.459    0.615
# 6               KOPER  145.961          5.799  1696.559  0.667    0.560
# 7               KRSKO  145.176          5.771  1664.412  0.528    0.448
# 8               CELJE  144.725          5.767  1648.889  0.448    0.433
# 9           LJUBLJANA  144.259          5.757  1675.942  0.365    0.393
# 10         NOVO MESTO  142.203          5.658  1620.720  0.000    0.000
#
#      ccm%  |ccm% - gorivo%|
# 0   0.676             0.324
# 1   0.694             0.223
# 2   0.000             0.798
# 3   0.508             0.274
# 4   0.384             0.366
# 5   0.418             0.197
# 6   1.000             0.440
# 7   0.736             0.288
# 8   0.608             0.175
# 9   0.831             0.438
# 10  0.377             0.377

# %% [markdown]
# Stolpec z odstotki je dodan, da lahko z grafa razberemo (ne)ujemanje med porabo goriva in izpustom CO2.

# %%
PORABA[['gorivo%', 'CO2%']].plot(kind='bar', color=('red', 'black'))
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# Poraba goriva se po regijah kar dobro ujema z izpustom CO2. Izjema je le Murska Sobota.

# %% [markdown]
# Poglejmo še graf, ki ga dobimo brez združenja po regijah. To nam bo povedalo več o lastnostih, ki niso odvisne od regije in jih lahko, seveda z zadržkom, posplošimo vsaj na evropske avtomobile.

# %%
brez = tabela[['Poraba goriva', 'CO2']].sort_values('CO2')

max_poraba = max(brez['Poraba goriva'])
max_CO2 = max(brez['CO2'])
min_poraba = min(brez['Poraba goriva'])
min_CO2 = min(brez['CO2'])

brez['Poraba goriva%'] = round((brez['Poraba goriva'] - min_poraba) / (max_poraba - min_poraba), 3)
brez['CO2%'] = round((brez['CO2'] - min_CO2) / (max_CO2 - min_CO2), 3)

brez.plot.scatter('Poraba goriva%', 'CO2%', s=1)
plt.plot([0,1], [0,1], color='grey')
plt.xlim(0,1)
plt.ylim(0,1)
# Out:
# (0, 1)

# %% [markdown]
# ## 2.3 Večja prostornina, večja poraba

# %% [markdown]
# Preverimo, v kolikšni meri drži intuitivna misel, da večja prostornina pomeni večjo porabo. To bomo ugotovili, če izračunamo razliko med odstkovno prostornino in porabo goriva. Naj bi torej veljalo, da tam, kjer imajo avtomobili večjo prostornino, imajo tudi večjo porabo.

# %%
razlika = PORABA['|ccm% - gorivo%|']
razlika.sort_values(ascending=False).plot(kind='bar')

# %%
izracun = pd.DataFrame(razlika).sort_values('|ccm% - gorivo%|', ascending=False).reset_index()

# izpustimo največje in najmanjše odstopanje
za_izracun = izracun[1:-1]

round(za_izracun['|ccm% - gorivo%|'].mean(), 3)
# Out:
# 0.325

# %% [markdown]
# Povprečno odstopanje nam da idejo o veljavnosti. Vidimo, da to zelo pogosto ne pomeni prav veliko.

# %% [markdown]
# ## 2.4 V glavnem mestu se je treba napihovati

# %% [markdown]
# Po svetu velja, da so ljudje iz večjih mest bolj naduti. Ali to pomeni, da imajo tudi močnejše avtomobile?

# %%
moc = tabela[['Registrsko obmocje', 'Moc', 'ccm']]
moc_kraji = round(moc.groupby('Registrsko obmocje')[['Moc', 'ccm']].mean(), 3)
MOC = pd.DataFrame(moc_kraji).sort_values('Moc', ascending=False)

MOC['Moc%'] = round((MOC['Moc'] - min(MOC['Moc'])) / (max(MOC['Moc']) - min(MOC['Moc'])), 3)
MOC['ccm%'] = round((MOC['ccm'] - min(MOC['ccm'])) / (max(MOC['ccm']) - min(MOC['ccm'])), 3)

MOC['|Moc% - ccm%|'] = abs(MOC['Moc%'] - MOC['ccm%'])

MOC.reset_index()
# Out:
#    Registrsko obmocje     Moc       ccm   Moc%   ccm%  |Moc% - ccm%|
# 0               KOPER  86.029  1696.559  1.000  1.000          0.000
# 1           LJUBLJANA  85.888  1675.942  0.981  0.831          0.150
# 2            POSTOJNA  83.766  1621.582  0.691  0.384          0.307
# 3      SLOVENJ GRADEC  83.466  1659.261  0.650  0.694          0.044
# 4         NOVA GORICA  82.423  1657.053  0.507  0.676          0.169
# 5               KRANJ  82.194  1636.617  0.476  0.508          0.032
# 6               CELJE  82.190  1648.889  0.476  0.608          0.132
# 7             MARIBOR  81.725  1625.649  0.412  0.418          0.006
# 8               KRSKO  81.568  1664.412  0.391  0.736          0.345
# 9          NOVO MESTO  80.050  1620.720  0.183  0.377          0.194
# 10      MURSKA SOBOTA  78.708  1574.804  0.000  0.000          0.000

# %%
MOC[['Moc%', 'ccm%']].plot(kind='bar', color=('yellow', 'brown'))

# %% [markdown]
# Spoznamo, da v Sloveniji ta hipoteza skoraj velja.
#
# Zanima nas še, kako sta med seboj odvisna moč in prostornina.

# %%
round(MOC['|Moc% - ccm%|'].mean(), 3)
# Out:
# 0.125

# %% [markdown]
# Vidimo, da sta ta dva parametra kar dobro usklajena.

# %% [markdown]
# # 3. Še nekaj zanimivosti

# %% [markdown]
# ## 3.1 Za več moči je potrebnega več goriva

# %% [markdown]
# Preverili bomo še eno izmed zanimivih hipotez in sicer, ali je za več moči res treba bolj pogosto obiskovati bencinske črpalke?

# %%
po_moci = round(tabela.groupby('Moc')['Poraba goriva'].mean(), 3)
MOC_PORABA = pd.DataFrame(po_moci)
MP = MOC_PORABA.reset_index()
MP.plot.scatter('Moc', 'Poraba goriva') #(kind='line', color='black')
plt.xlim(0,500)
plt.ylim(0,24)
# Out:
# (0, 24)

# %% [markdown]
# Torej drži, da imajo v povprečju močnejši avtomobili večjo porabo goriva.
# Opazimo pa še velika nihanja v območju med 150 in 180 konjskimi močmi. Sklepamo, da je to zaradi zelo široke ponudbe avtomobilov s tako močjo in tudi zaradi izboljševanja izkoriščenosti goriva skozi leta. S tem mislimo, da ima avtomobil s 150KM iz leta 2000 dosti večjo porabo kot enako močan iz leta 2016.

# %% [markdown]
# ## 3.2 Kako se z leti izboljšuje učinkovitost

# %% [markdown]
# Preverimo torej, kako se z višanjem oznake EURO zmanjšuje izpust CO2.
#
# Več o oznaki lahko preberete tu: https://en.wikipedia.org/wiki/European_emission_standards.

# %%
tabela = tabela[tabela['Leto izdelave'] > 1991] #omejimo se na obdobje, ko so uvedli EURO 0
po_euro = round(tabela.groupby('Okoljevarstvena oznaka')[['Leto izdelave', 'CO2', 'Poraba goriva']].mean(), 3)
evro = pd.DataFrame(po_euro)

EURO = evro.reset_index()

EURO.index = ["EURO " + str(i) for i in range(0,7)]
EURO

xy = EURO['CO2'].plot(kind='bar')
xy.set_ylabel('CO2 g/km')

# %% [markdown]
# Opazimo, da se z oznako znižujejo emisije, kot smo tudi pričakovali.
#
# Pri EURO 0 vrednosti odstopajo zaradi nepopolnih podatkov za tako stare avtomobile.

# %%
co2_leto = round(tabela.groupby('Leto izdelave')[['CO2', 'Okoljevarstvena oznaka']].mean(), 3)
CL = pd.DataFrame(co2_leto)
CO2 = CL['CO2']
clplt = CO2.plot(kind='line')
clplt.set_ylim([100,300])
clplt.set_ylabel('CO2 g/km')

# %%
OKOL = CL['Okoljevarstvena oznaka']
OKOL
clplt = OKOL.plot(kind='line', color='green')
clplt.set_ylabel('Oznaka EURO')

# %% [markdown]
# Tudi zmanjševanje izpustov skozi čas je pričakovano, oznake pa se seveda primerno zvišujejo.

# %% [markdown]
# ## 3.3 Kako je najvišja hitrost odvisna od moči

# %% [markdown]
# Treba je seveda dodati, da najvišja hitrost ni odvisna le od moči motorja. Pomembno še navor, vendar tega podatka nimamo, zato se v tem razdelku osredotočimo le na moč.

# %%
hm = tabela[['Najvisja hitrost', 'Moc']]
HM = pd.DataFrame(hm.groupby('Moc').mean())
HM.plot(kind='line')

# %% [markdown]
# Pogled na graf namiguje na logaritemsko odvisnost.

# %% [markdown]
# # 4. Kako so parametri odvisni od znamk

# %%
moc_zn = round(tabela.groupby('Znamka').mean(), 3)
NAJMOC = pd.DataFrame(moc_zn)
NAJMOC.reset_index()[:10]
# Out:
#                Znamka      Masa       ccm      Moc  Najvisja hitrost      CO2  \
# 0              ABARTH  1165.000  1368.000  132.000           225.000  134.000
# 1               AHORN  2937.000  2299.000   92.000           128.000  216.000
# 2          ALFA ROMEO  1465.248  1895.299  104.668           203.647  162.021
# 3                 API  1673.000  1560.000   68.000           165.000  125.000
# 4        ASTON MARTIN  1855.000  5935.000  350.667           298.333  385.000
# 5                AUDI  1614.944  2081.124  113.055           209.774  154.457
# 6  AUTOCARAVANS RIMOR  2992.500  2299.000  101.000           133.000  227.500
# 7             BENIMAR  3029.250  2253.625  104.375           151.312  197.250
# 8             BENTLEY  2513.750  5998.000  412.000           320.250  410.000
# 9             BLUCAMP  2951.000  2299.000  100.000           151.000  190.000
#
#    Poraba goriva  Okoljevarstvena oznaka  Leto izdelave
# 0          5.800                   6.000       2015.000
# 1          8.200                   5.000       2015.000
# 2          6.292                   3.862       2006.744
# 3          4.800                   5.000       2012.000
# 4         16.167                   4.000       2008.667
# 5          5.913                   4.461       2009.020
# 6          8.700                   5.000       2013.500
# 7          7.494                   5.000       2015.562
# 8         17.100                   3.750       2006.250
# 9          7.200                   5.000       2016.000

# %% [markdown]
# ## 4.1 Avtomobili katerih znamk so najmočnejši

# %%
N = NAJMOC.sort_values('Moc', ascending=False).reset_index()
N[['Znamka', 'Moc']][:10]
# Out:
#          Znamka      Moc
# 0       BENTLEY  412.000
# 1       FERRARI  363.333
# 2  ASTON MARTIN  350.667
# 3       QUATTRO  321.412
# 4      MASERATI  288.143
# 5      CADILLAC  246.625
# 6       PORSCHE  239.017
# 7       PONTIAC  194.000
# 8           KTM  177.000
# 9      INFINITI  165.222

# %% [markdown]
# Najmočnejši so torej bolj eksotični avtomobili, ki jih le redko vidimo na cesti.

# %% [markdown]
# ## 4.2 Najpogostejše znamke

# %% [markdown]
# Primerjajmo v Sloveniji najpogostejše znamke.

# %%
TRI = N.loc[N['Znamka'].isin(['RENAULT', 'VOLKSWAGEN', 'OPEL', 'CITROEN', 'PEUGEOT', 'FORD', 'SKODA', 'AUDI', 'BMW', 'HYUNDAI'])].sort_values('Poraba goriva', ascending=False)
#(df.loc[df['A'] == 'foo'])
TRI
# Out:
#         Znamka      Masa       ccm      Moc  Najvisja hitrost      CO2  \
# 61     HYUNDAI  1489.168  1723.679   88.533           177.592  155.039
# 16         BMW  1655.885  2251.149  131.649           219.306  157.978
# 24        AUDI  1614.944  2081.124  113.055           209.774  154.457
# 71        OPEL  1364.300  1554.402   79.901           183.608  145.615
# 72        FORD  1337.580  1591.505   79.844           181.763  143.236
# 76     CITROEN  1350.185  1598.466   75.840           179.748  145.352
# 77     PEUGEOT  1325.865  1549.196   75.798           183.151  140.801
# 82     RENAULT  1264.444  1417.186   70.733           177.507  139.229
# 67  VOLKSWAGEN  1438.122  1728.345   83.440           189.191  139.070
# 74       SKODA  1302.337  1573.005   78.762           188.852  129.942
#
#     Poraba goriva  Okoljevarstvena oznaka  Leto izdelave
# 61          6.183                   4.250       2009.115
# 16          6.056                   4.530       2009.069
# 24          5.913                   4.461       2009.020
# 71          5.896                   4.467       2009.138
# 72          5.787                   4.325       2009.268
# 76          5.767                   4.188       2009.013
# 77          5.716                   4.335       2009.221
# 82          5.666                   4.249       2009.095
# 67          5.428                   4.566       2009.713
# 74          5.225                   4.777       2011.310

# %% [markdown]
# Iz tabele lahko razberemo, nekaj zanimivih stvari.
#
# Škodini avtomobili so približno 2 leti novejši od ostalih.
#
# Hyundaijevi avtomobili imajo glede na prostornino in moč motorjev izrazito visoko porabo goriva.
#
# Glede na to, da BMW predstavlja več kot 5% slovenskih avtomobilov, so le-ti relativno močni in hitri.
#
# Zanimivo so Renaultovi avtomobili najšibkejši med prvimi desetimi najpogostejšimi znamkami, predstavljajo pa največji delež v Sloveniji.
